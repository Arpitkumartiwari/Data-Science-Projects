# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime

# %%
df = pd.read_csv('worldometer_snapshots_April18_to_May18.csv')
df
# Out:
#             Date                Country  Population  Total Tests  Total Cases  \
# 0     2020-04-18                    USA   330774664    3722145.0     738792.0
# 1     2020-04-18                 Russia   145927292    1831892.0      36793.0
# 2     2020-04-18                  Spain    46752703     930230.0     194416.0
# 3     2020-04-18                 Brazil   212380932      62985.0      36722.0
# 4     2020-04-18                     UK    67844241     460437.0     114217.0
# ...          ...                    ...         ...          ...          ...
# 6598  2020-05-18              St. Barth        9874          NaN          6.0
# 6599  2020-05-18         Western Sahara      595462          NaN          6.0
# 6600  2020-05-18               Anguilla       14987          NaN          3.0
# 6601  2020-05-18                Lesotho     2140235          NaN          1.0
# 6602  2020-05-18  Saint Pierre Miquelon        5797          NaN          1.0
#
# ...

# %% [markdown]
# ## FOR USA ONLY

# %%
country_name = 'USA'
df1 = df.loc[df['Country'] == country_name, :].reset_index(drop=True)
df1
# Out:
#           Date Country  Population  Total Tests  Total Cases  Total Deaths  \
# 0   2020-04-18     USA   330774664    3722145.0     738792.0       39014.0
# 1   2020-04-19     USA   330774664    3861549.0     763832.0       40553.0
# 2   2020-04-20     USA   330774664    4026360.0     792759.0       42514.0
# 3   2020-04-21     USA   330774664    4187392.0     818744.0       45318.0
# 4   2020-04-22     USA   330774664    4325342.0     848717.0       47659.0
# 5   2020-04-23     USA   330774664    4696704.0     880204.0       49845.0
# 6   2020-04-24     USA   330774664    5015602.0     925038.0       52185.0
# 7   2020-04-25     USA   330774664    5279237.0     960651.0       54256.0
# 8   2020-04-26     USA   330774664    5470464.0     987160.0       55413.0
# 9   2020-04-27     USA   330774664    5696928.0    1010356.0       56797.0
# 10  2020-04-28     USA   330774664    5919847.0    1035765.0       59266.0
# ...

# %% [markdown]
# ### FOR DATE (2020-05-18)

# %%
df2= datetime.strptime('18/05/2020', '%d/%m/%Y')

df2 = df.loc[df['Date'] == df2.strftime('%Y-%m-%d'), :].reset_index(drop=True)
df2
# Out:
#            Date                Country  Population  Total Tests  Total Cases  \
# 0    2020-05-18                    USA   330774664   12300744.0    1550294.0
# 1    2020-05-18                 Russia   145927292    7147014.0     290678.0
# 2    2020-05-18                  Spain    46752703    3037840.0     278188.0
# 3    2020-05-18                 Brazil   212380932     735224.0     255368.0
# 4    2020-05-18                     UK    67844241    2682716.0     246406.0
# ..          ...                    ...         ...          ...          ...
# 208  2020-05-18              St. Barth        9874          NaN          6.0
# 209  2020-05-18         Western Sahara      595462          NaN          6.0
# 210  2020-05-18               Anguilla       14987          NaN          3.0
# 211  2020-05-18                Lesotho     2140235          NaN          1.0
# 212  2020-05-18  Saint Pierre Miquelon        5797          NaN          1.0
#
# ...

# %% [markdown]
# ### FOR LAST DATE - (2020-05-18)

# %%
df3 = datetime.strptime('18/05/2020', '%d/%m/%Y')

df3 = df.loc[df['Date'] == df3.strftime('%Y-%m-%d'), :].reset_index(drop=True)
df3
# Out:
#            Date                Country  Population  Total Tests  Total Cases  \
# 0    2020-05-18                    USA   330774664   12300744.0    1550294.0
# 1    2020-05-18                 Russia   145927292    7147014.0     290678.0
# 2    2020-05-18                  Spain    46752703    3037840.0     278188.0
# 3    2020-05-18                 Brazil   212380932     735224.0     255368.0
# 4    2020-05-18                     UK    67844241    2682716.0     246406.0
# ..          ...                    ...         ...          ...          ...
# 208  2020-05-18              St. Barth        9874          NaN          6.0
# 209  2020-05-18         Western Sahara      595462          NaN          6.0
# 210  2020-05-18               Anguilla       14987          NaN          3.0
# 211  2020-05-18                Lesotho     2140235          NaN          1.0
# 212  2020-05-18  Saint Pierre Miquelon        5797          NaN          1.0
#
# ...

# %% [markdown]
# ### PERCENTAGE OF DEATH RATE SHOULD BE (TOTAL DEATH/TOTAL CASES)*100

# %%
df3['Case Fatality Ratio'] = df3['Total Deaths'] / df3['Total Cases']
plt.figure(figsize=(12,8))
plt.hist(100 * np.array(df3['Case Fatality Ratio']), bins=np.arange(35))
plt.xlabel('Death Rate (%)', fontsize=16)
plt.ylabel('Number of Countries', fontsize=16)
plt.title('Histogram of Death Rates for various Countries', fontsize=18)
plt.show()

# %% [markdown]
# ## COUNTRIES WHOE WERE AT HIGH RISK

# %% [markdown]
#    LETS TAKE A THRESHOLD AS 1000 CASES

# %%
min_number_of_cases = 1000
df4 = df3.loc[df3['Total Cases'] > min_number_of_cases,:]
plt.figure(figsize=(12,8))
plt.hist(100 * np.array(df4['Case Fatality Ratio']), bins=np.arange(20))
plt.xlabel('Death Rate (%)', fontsize=16)
plt.ylabel('Number of Countries', fontsize=16)
plt.title('Histogram of Death Rates for various Countries', fontsize=18)
plt.show()

# %% [markdown]
# # COUNTRIES WHO HAD HIGH COVID 19 CASES

# %%
df[df['Total Cases'] > min_number_of_cases].Country.unique()
# Out:
# array(['USA', 'Russia', 'Spain', 'Brazil', 'UK', 'Italy', 'France',
#        'Germany', 'Turkey', 'Iran', 'India', 'Peru', 'China', 'Canada',
#        'Saudi Arabia', 'Belgium', 'Mexico', 'Chile', 'Netherlands',
#        'Pakistan', 'Qatar', 'Ecuador', 'Switzerland', 'Belarus', 'Sweden',
#        'Portugal', 'Singapore', 'Ireland', 'UAE', 'Bangladesh', 'Poland',
#        'Ukraine', 'Indonesia', 'Romania', 'Israel', 'South Africa',
#        'Japan', 'Colombia', 'Austria', 'Kuwait', 'Egypt',
#        'Dominican Republic', 'Philippines', 'S. Korea', 'Denmark',
#        'Serbia', 'Panama', 'Czechia', 'Argentina', 'Norway', 'Algeria',
#        'Bahrain', 'Australia', 'Morocco', 'Malaysia', 'Kazakhstan',
#        'Finland', 'Moldova', 'Oman', 'Armenia', 'Luxembourg', 'Iraq',
#        'Hungary', 'Cameroon', 'Azerbaijan', 'Thailand', 'Greece',
#        'Uzbekistan', 'Bosnia and Herzegovina', 'Croatia',
#        'North Macedonia', 'Iceland', 'Estonia', 'Lithuania',
# ...

# %% [markdown]
# # THE END
